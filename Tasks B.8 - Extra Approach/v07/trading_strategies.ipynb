# %% [markdown]
# # Simulating Stock Trading Strategies with SMA and RSI Indicators

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

from backtesting import Backtest, Strategy
from backtesting.lib import crossover
from backtesting.test import SMA, GOOG

# %% [markdown]
# ## Data Preprocessing

# %%
# Data Collection
ticker = 'AAPL'
stock_data = yf.download(ticker, start='2020-01-01', end='2024-01-01')
stock_data.info()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2020-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1006 non-null   float64
#  1   High       1006 non-null   float64
#  2   Low        1006 non-null   float64
#  3   Close      1006 non-null   float64
#  4   Adj Close  1006 non-null   float64
#  5   Volume     1006 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 55.0 KB

# %%
stock_data.describe().T
# Out:
#             count          mean           std           min           25%  \
# Open       1006.0  1.406755e+02  3.331002e+01  5.702000e+01  1.236825e+02
# High       1006.0  1.423214e+02  3.343057e+01  5.712500e+01  1.250300e+02
# Low        1006.0  1.391435e+02  3.317920e+01  5.315250e+01  1.221575e+02
# Close      1006.0  1.408081e+02  3.331386e+01  5.609250e+01  1.235925e+02
# Adj Close  1006.0  1.388642e+02  3.357695e+01  5.456973e+01  1.211879e+02
# Volume     1006.0  9.895211e+07  5.439653e+07  2.404830e+07  6.407675e+07
#
#                     50%           75%           max
# Open       1.455400e+02  1.663025e+02  1.980200e+02
# High       1.472650e+02  1.681475e+02  1.996200e+02
# Low        1.441200e+02  1.648150e+02  1.970000e+02
# Close      1.458600e+02  1.662150e+02  1.981100e+02
# Adj Close  1.437545e+02  1.642670e+02  1.973611e+02
# Volume     8.467540e+07  1.155069e+08  4.265100e+08

# %% [markdown]
# ## BackTesting Environment (2015 - 2019)

# %%
class SmaCross(Strategy):
    def init(self):
        price = self.data.Close
        self.ma1 = self.I(SMA, price, 10)
        self.ma2 = self.I(SMA, price, 20)
    def next(self):
        if crossover(self.ma1, self.ma2):
            self.buy()
        elif crossover(self.ma2, self.ma1):
            self.sell()
            
historical_data = yf.download('AAPL', start='2015-01-01', end='2019-01-01')
backtest = Backtest(historical_data, SmaCross, commission=.002, exclusive_orders=True)
stats = backtest.run()

backtest.plot(filename='backtest_results.html', open_browser=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# BokehDeprecationWarning: Passing lists of formats for DatetimeTickFormatter scales was deprecated in Bokeh 3.0. Configure a single string format for each scale
# /opt/anaconda3/lib/python3.12/site-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%d %b'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# BokehDeprecationWarning: Passing lists of formats for DatetimeTickFormatter scales was deprecated in Bokeh 3.0. Configure a single string format for each scale
# /opt/anaconda3/lib/python3.12/site-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%m/%Y'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# /opt/anaconda3/lib/python3.12/site-packages/backtesting/_plotting.py:456: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample(resample_rule, label='left')
# /opt/anaconda3/lib/python3.12/site-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   fig = gridplot(
# /opt/anaconda3/lib/python3.12/site-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   fig = gridplot(
# GridPlot(id='p1325', ...)

# %% [markdown]
# ## Buy/Sell Decision Based on Stock Closing Prices

# %%
import time
import numpy as np
import datetime as dt
import yfinance as yf

def calculate_rsi(prices, period=14):
    delta = np.diff(prices)
    gain = np.maximum(delta, 0)
    loss = np.abs(np.minimum(delta, 0))

    avg_gain = np.mean(gain[:period])
    avg_loss = np.mean(loss[:period])

    rsi = []
    for i in range(period, len(prices)):
        avg_gain = (avg_gain * (period - 1) + gain[i - period]) / period
        avg_loss = (avg_loss * (period - 1) + loss[i - period]) / period
        rs = avg_gain / avg_loss if avg_loss != 0 else 0
        rsi_value = 100 - (100 / (1 + rs))
        rsi.append(rsi_value)

    return rsi

def trade_yfinance():
    ticker = 'AAPL'
    data = yf.download(ticker, period='1mo', interval='1h')  # Download 1 month of hourly data
    close_prices = data['Close'].tolist()  # Convert the close prices to a list for simulation

    # Parameters for SMA calculation
    sma_short_period = 10
    sma_long_period = 20
    rsi_period = 14

    # Stop-loss and take-profit parameters (percentage)
    stop_loss_pct = 0.02  # 2% stop loss
    take_profit_pct = 0.04  # 4% take profit

    # Variables for simulation
    current_position = None
    cash = 100000  # Initial virtual cash
    stock_qty = 0
    entry_price = 0
    start_time = dt.datetime.now()
    max_duration = dt.timedelta(minutes=5)  # Simulate for 5 minutes
    index = 0
    total_profit = 0  # Track total profit or loss

    while True:
        # Check if the script has run for longer than the max duration
        if dt.datetime.now() - start_time > max_duration:
            print("Stopping the script after 5 minutes.")
            break

        print("Running simulation loop...")

        # Get the current price
        if index < len(close_prices):
            current_price = close_prices[index]
            index += 1
        else:
            print("End of historical price data.")
            break

        # Extract Close Prices for SMA Calculation (take the last `sma_long_period` prices)
        if index >= sma_long_period:
            recent_prices = close_prices[index - sma_long_period:index]

            # Calculate Moving Averages
            sma_short = np.mean(recent_prices[-sma_short_period:])
            sma_long = np.mean(recent_prices)

            # Calculate RSI
            if index >= sma_long_period + rsi_period:
                rsi_values = calculate_rsi(close_prices[index - (sma_long_period + rsi_period):index], rsi_period)
                rsi = rsi_values[-1]
            else:
                continue

            # Debug information for moving averages and RSI
            print(f"SMA Short: {sma_short}, SMA Long: {sma_long}, RSI: {rsi}")

            # Buy Signal with Relaxed RSI Confirmation
            if sma_short > sma_long and current_position is None and rsi < 40:
                qty = int(cash // current_price)
                if qty > 0:
                    stock_qty = qty
                    cash -= stock_qty * current_price
                    entry_price = current_price
                    current_position = 'long'
                    print(f"Bought {stock_qty} shares at {current_price}, Remaining Cash: {cash}")

            # Stop-loss or Take-profit check
            if current_position == 'long':
                # Stop-loss triggered
                if current_price <= entry_price * (1 - stop_loss_pct):
                    cash += stock_qty * current_price
                    profit = (current_price - entry_price) * stock_qty
                    total_profit += profit
                    print(f"Stop-Loss Triggered: Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
                    stock_qty = 0
                    current_position = None

                # Take-profit triggered
                elif current_price >= entry_price * (1 + take_profit_pct):
                    cash += stock_qty * current_price
                    profit = (current_price - entry_price) * stock_qty
                    total_profit += profit
                    print(f"Take-Profit Triggered: Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
                    stock_qty = 0
                    current_position = None

            # Sell Signal with Relaxed RSI Confirmation
            elif sma_short < sma_long and current_position == 'long' and rsi > 60:
                cash += stock_qty * current_price
                profit = (current_price - entry_price) * stock_qty
                total_profit += profit
                print(f"Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
                stock_qty = 0
                current_position = None

            # Debug profit/loss tracking
            print(f"Total Profit/Loss so far: {total_profit}")

        time.sleep(1)

    # Final evaluation of performance
    if current_position == 'long':
        # Sell any remaining stock at the last available price
        cash += stock_qty * current_price
        profit = (current_price - entry_price) * stock_qty
        total_profit += profit
        print(f"Final Sale: Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
        stock_qty = 0
        current_position = None

    print(f"Total Profit/Loss at the end of simulation: {total_profit}")

trade_yfinance()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# Running simulation loop...
# SMA Short: 226.17301025390626, SMA Long: 226.60627975463868, RSI: 39.49120140669107
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.08000946044922, SMA Long: 226.52127990722656, RSI: 40.57542703984777
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.08209838867188, SMA Long: 226.43360977172853, RSI: 42.86405270932569
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.11846771240235, SMA Long: 226.45609436035156, RSI: 44.81758863427945
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.11346740722655, SMA Long: 226.48459396362304, RSI: 44.06549074588909
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.19046783447266, SMA Long: 226.50834426879882, RSI: 41.02472385579424
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.4159683227539, SMA Long: 226.57909469604493, RSI: 43.087974255913224
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.58645782470703, SMA Long: 226.6353446960449, RSI: 41.48751418279277
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.8124572753906, SMA Long: 226.71284408569335, RSI: 39.2426738383142
# Bought 439 shares at 227.6199951171875, Remaining Cash: 74.8221435546875
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.21754760742186, SMA Long: 226.80978393554688, RSI: 31.27952410789203
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.50455780029296, SMA Long: 226.83878402709962, RSI: 35.42196660322283
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.68855743408204, SMA Long: 226.88428344726563, RSI: 34.87788753798304
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.79805755615234, SMA Long: 226.9400779724121, RSI: 25.757896241512228
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.8485885620117, SMA Long: 226.98352813720703, RSI: 36.10808727078122
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.89858856201172, SMA Long: 227.00602798461915, RSI: 45.02232006951045
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.9650894165039, SMA Long: 227.0777786254883, RSI: 45.80698003897135
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 228.29258880615234, SMA Long: 227.35427856445312, RSI: 54.99464134277368
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 228.72508850097657, SMA Long: 227.6557731628418, RSI: 53.94710211906855
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 229.17508850097656, SMA Long: 227.9937728881836, RSI: 51.83350479072515
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 229.44449920654296, SMA Long: 228.3310234069824, RSI: 57.46339679014141
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 229.7324981689453, SMA Long: 228.61852798461913, RSI: 57.15158225924952
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 230.03949890136718, SMA Long: 228.8640281677246, RSI: 59.76500172368355
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 230.53999938964844, SMA Long: 229.16902847290038, RSI: 65.49859589419971
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 230.24649963378906, SMA Long: 229.04754409790038, RSI: 56.51386205764609
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 230.01300048828125, SMA Long: 228.95579452514647, RSI: 57.389245482831384
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 229.76230010986328, SMA Long: 228.8636947631836, RSI: 58.15150881914867
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 229.0572998046875, SMA Long: 228.67494430541993, RSI: 56.444209822870604
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 228.41330108642578, SMA Long: 228.56919479370117, RSI: 54.509534622712984
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.81631164550782, SMA Long: 228.49570007324218, RSI: 61.586065105923204
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 227.2778106689453, SMA Long: 228.36115493774415, RSI: 78.61840430073343
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.71881103515625, SMA Long: 228.22565460205078, RSI: 80.37806473798312
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.2173110961914, SMA Long: 228.1284049987793, RSI: 82.76421308589924
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.61251068115234, SMA Long: 228.07625503540038, RSI: 79.49625433259888
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.8125, SMA Long: 228.02949981689454, RSI: 72.26591591119514
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.9470001220703, SMA Long: 227.9800003051758, RSI: 71.2212669423233
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.13970031738282, SMA Long: 227.95100021362305, RSI: 78.48158539406317
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.42770080566407, SMA Long: 227.74250030517578, RSI: 39.76556519153635
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.36520080566407, SMA Long: 227.3892509460449, RSI: 42.322895450082434
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.23761138916015, SMA Long: 227.02696151733397, RSI: 42.08396266169254
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 226.1187316894531, SMA Long: 226.69827117919922, RSI: 37.25069537535566
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.96023254394532, SMA Long: 226.3395217895508, RSI: 43.89763890632388
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.72374267578124, SMA Long: 225.97052688598632, RSI: 47.9106100485717
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.39854278564454, SMA Long: 225.50552673339843, RSI: 41.252650596789714
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.2695526123047, SMA Long: 225.54102630615233, RSI: 40.422858161585
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.03860168457032, SMA Long: 225.4928009033203, RSI: 43.25533373546944
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.77060089111328, SMA Long: 225.45515060424805, RSI: 45.20828455561578
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.58460083007813, SMA Long: 225.5061508178711, RSI: 46.47315193178878
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.6111099243164, SMA Long: 225.48815536499023, RSI: 46.660486087331336
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.6326889038086, SMA Long: 225.43515014648438, RSI: 48.244615989401
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.73457946777344, SMA Long: 225.4266555786133, RSI: 40.24192711431586
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.0290786743164, SMA Long: 225.49465560913086, RSI: 33.51261864272632
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.17706909179688, SMA Long: 225.45040588378907, RSI: 34.04824651324944
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.31307983398438, SMA Long: 225.35581130981444, RSI: 35.67107247104701
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.17207946777344, SMA Long: 225.22081604003907, RSI: 33.04730496943384
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.1020294189453, SMA Long: 225.0703155517578, RSI: 33.17483626384433
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 225.0210189819336, SMA Long: 224.89580993652345, RSI: 27.854493473296245
# Total Profit/Loss so far: 0
# Running simulation loop...
# SMA Short: 224.78251953125, SMA Long: 224.68356018066407, RSI: 52.08197133768999
# Stop-Loss Triggered: Sold 439 shares at 222.56500244140625, Profit: -2219.1417846679688, New Cash Balance: 97780.85821533203
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.44450988769532, SMA Long: 224.52780990600587, RSI: 44.911048676004924
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.42550964355468, SMA Long: 224.52909927368165, RSI: 45.84024128295508
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.34949951171876, SMA Long: 224.5420394897461, RSI: 50.02277748394603
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.15350036621095, SMA Long: 224.59128952026367, RSI: 46.58368240588654
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.09550018310546, SMA Long: 224.63628463745118, RSI: 43.867282712740206
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.08246002197265, SMA Long: 224.69776992797853, RSI: 53.2675941649012
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.18346099853517, SMA Long: 224.6777702331543, RSI: 57.774538237432196
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.38046112060547, SMA Long: 224.7412452697754, RSI: 46.580931666966684
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 224.71547241210936, SMA Long: 224.86824569702148, RSI: 43.48378465870733
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 225.27797241210936, SMA Long: 225.03024597167968, RSI: 39.66877762051807
# Bought 428 shares at 228.19000244140625, Remaining Cash: 115.53717041015625
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 225.9769729614258, SMA Long: 225.21074142456055, RSI: 37.894517124294346
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 226.3729736328125, SMA Long: 225.39924163818358, RSI: 37.91635882470552
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 226.80297393798827, SMA Long: 225.57623672485352, RSI: 34.932736286427314
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 227.2283935546875, SMA Long: 225.69094696044922, RSI: 34.0742009728463
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 227.70539245605468, SMA Long: 225.90044631958008, RSI: 52.158841905000244
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.03797149658203, SMA Long: 226.06021575927736, RSI: 52.74289568849985
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.33997039794923, SMA Long: 226.2617156982422, RSI: 52.39588659519222
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.63297119140626, SMA Long: 226.50671615600587, RSI: 51.87176883262014
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.7729705810547, SMA Long: 226.74422149658204, RSI: 51.68628636705925
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.78597106933594, SMA Long: 227.03197174072267, RSI: 47.53181267172842
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.80046997070312, SMA Long: 227.38872146606445, RSI: 56.85323506322006
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.81746978759764, SMA Long: 227.59522171020507, RSI: 62.66213982601153
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.73046875, SMA Long: 227.76672134399413, RSI: 65.01972890820977
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.62054901123048, SMA Long: 227.924471282959, RSI: 66.13814420148225
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.4525588989258, SMA Long: 228.07897567749023, RSI: 66.49933273625436
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.4110092163086, SMA Long: 228.2244903564453, RSI: 67.50116740806553
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.4015106201172, SMA Long: 228.3707405090332, RSI: 62.66858109541794
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.3995101928711, SMA Long: 228.51624069213867, RSI: 69.71414381454932
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.3015106201172, SMA Long: 228.53724060058593, RSI: 62.54755172901425
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.5380096435547, SMA Long: 228.6619903564453, RSI: 65.57574040711188
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.62151031494142, SMA Long: 228.71099014282225, RSI: 68.81599665824054
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.74346008300782, SMA Long: 228.78046493530275, RSI: 68.135195450032
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 228.91045989990235, SMA Long: 228.82046432495116, RSI: 70.1946422412183
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 229.1589599609375, SMA Long: 228.88975448608397, RSI: 75.99254284596724
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 229.49821014404296, SMA Long: 228.9753845214844, RSI: 68.6469330033664
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 229.84421081542968, SMA Long: 229.12761001586915, RSI: 64.95504709827279
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 230.6067108154297, SMA Long: 229.50411071777344, RSI: 60.2729049275125
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.28085021972657, SMA Long: 229.84018020629884, RSI: 59.13753833219417
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.00484924316407, SMA Long: 230.15317993164064, RSI: 58.55586118275933
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.33834991455078, SMA Long: 230.43817977905275, RSI: 60.95363093791243
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.7633499145508, SMA Long: 230.6924301147461, RSI: 63.086617163667576
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.0624008178711, SMA Long: 230.90293045043944, RSI: 48.01482181838275
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.39940185546874, SMA Long: 231.15493087768556, RSI: 62.58914060751999
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.4263717651367, SMA Long: 231.29266586303712, RSI: 54.555715715574934
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.36261291503905, SMA Long: 231.430411529541, RSI: 56.864611710266956
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.26661224365233, SMA Long: 231.555411529541, RSI: 56.24613876148597
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.77560119628907, SMA Long: 231.69115600585937, RSI: 58.60806417134974
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.3434616088867, SMA Long: 231.81215591430663, RSI: 59.42244762039183
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.02896270751953, SMA Long: 232.01690597534179, RSI: 67.36584283134525
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.80196228027344, SMA Long: 232.0701560974121, RSI: 78.05796902140855
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.6479721069336, SMA Long: 232.20566101074218, RSI: 75.14348379585547
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.5499710083008, SMA Long: 232.30618591308593, RSI: 71.35622996116055
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.394970703125, SMA Long: 232.39718627929688, RSI: 67.25070814602401
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.56074066162108, SMA Long: 232.4935562133789, RSI: 66.49177833405393
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.6608901977539, SMA Long: 232.5117515563965, RSI: 62.05728521414255
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.8023910522461, SMA Long: 232.5345016479492, RSI: 67.76372326804156
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 231.9374008178711, SMA Long: 232.35650100708008, RSI: 54.40019396160922
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.30340118408202, SMA Long: 232.32343139648438, RSI: 53.84796096304707
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.6458999633789, SMA Long: 232.33743133544922, RSI: 52.505787513336166
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 232.96990051269532, SMA Long: 232.38593139648438, RSI: 54.28352343204723
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.25389099121094, SMA Long: 232.45093154907227, RSI: 53.791130069825094
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.58089141845704, SMA Long: 232.5654312133789, RSI: 58.944687745769464
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 233.88589172363282, SMA Long: 232.64043121337892, RSI: 50.26579408344955
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# SMA Short: 234.14715118408202, SMA Long: 232.85394592285155, RSI: 55.4828218452367
# Total Profit/Loss so far: -2219.1417846679688
# Running simulation loop...
# End of historical price data.
# Final Sale: Sold 428 shares at 235.0, Profit: 2914.678955078125, New Cash Balance: 100695.53717041016
# Total Profit/Loss at the end of simulation: 695.5371704101562

# %% [markdown]
# ## Buy/Sell Decision Using Full Stock Data

# %%
import time
import numpy as np
import datetime as dt
import yfinance as yf

def calculate_rsi(prices, period=14):
    delta = np.diff(prices)
    gain = np.maximum(delta, 0)
    loss = np.abs(np.minimum(delta, 0))

    avg_gain = np.mean(gain[:period])
    avg_loss = np.mean(loss[:period])

    rsi = []
    for i in range(period, len(prices)):
        avg_gain = (avg_gain * (period - 1) + gain[i - period]) / period
        avg_loss = (avg_loss * (period - 1) + loss[i - period]) / period
        rs = avg_gain / avg_loss if avg_loss != 0 else 0
        rsi_value = 100 - (100 / (1 + rs))
        rsi.append(rsi_value)

    return rsi

def trade_finance():
    ticker = 'AAPL'
    data = yf.download(ticker, period='1mo', interval='1h')  # Download 1 month of hourly data

    # Columns to use
    columns = ["High", "Low", "Open", "Close", "Volume", "Adj Close"]
    selected_data = data[columns].to_numpy()  # Convert selected columns to NumPy array

    # Extract individual columns
    high_prices = selected_data[:, 0]  # High prices
    low_prices = selected_data[:, 1]  # Low prices
    open_prices = selected_data[:, 2]  # Open prices
    close_prices = selected_data[:, 3]  # Close prices

    # Parameters for SMA calculation
    sma_short_period = 10
    sma_long_period = 20
    rsi_period = 14

    # Stop-loss and take-profit parameters (percentage)
    stop_loss_pct = 0.02  # 2% stop loss
    take_profit_pct = 0.04  # 4% take profit

    # Variables for simulation
    current_position = None
    cash = 100000  # Initial virtual cash
    stock_qty = 0
    entry_price = 0
    start_time = dt.datetime.now()
    max_duration = dt.timedelta(minutes=5)  # Simulate for 5 minutes
    index = 0
    total_profit = 0  # Track total profit or loss

    while True:
        # Check if the script has run for longer than the max duration
        if dt.datetime.now() - start_time > max_duration:
            print("Stopping the script after 5 minutes.")
            break

        # Get the current price
        if index < len(close_prices):
            current_price = close_prices[index]
            high_price = high_prices[index]  # Use High price
            low_price = low_prices[index]    # Use Low price
            index += 1
        else:
            print("End of historical price data.")
            break

        # Extract Close Prices for SMA Calculation (take the last `sma_long_period` prices)
        if index >= sma_long_period:
            recent_prices = close_prices[index - sma_long_period:index]

            # Calculate Moving Averages
            sma_short = np.mean(recent_prices[-sma_short_period:])
            sma_long = np.mean(recent_prices)

            # Calculate RSI using Close prices
            if index >= sma_long_period + rsi_period:
                rsi_values = calculate_rsi(close_prices[index - (sma_long_period + rsi_period):index], rsi_period)
                rsi = rsi_values[-1]
            else:
                continue

            # Debug information for moving averages and RSI
            print(f"SMA Short: {sma_short}, SMA Long: {sma_long}, RSI: {rsi}")

            # Buy Signal with Relaxed RSI Confirmation
            if sma_short > sma_long and current_position is None and rsi < 40:
                qty = int(cash // current_price)
                if qty > 0:
                    stock_qty = qty
                    cash -= stock_qty * current_price
                    entry_price = current_price
                    current_position = 'long'
                    print(f"Bought {stock_qty} shares at {current_price}, Remaining Cash: {cash}")

            # Stop-loss or Take-profit check based on High and Low prices
            if current_position == 'long':
                # Stop-loss triggered based on Low price
                if low_price <= entry_price * (1 - stop_loss_pct):
                    cash += stock_qty * low_price
                    profit = (low_price - entry_price) * stock_qty
                    total_profit += profit
                    print(f"Stop-Loss Triggered: Sold {stock_qty} shares at {low_price}, Profit: {profit}, New Cash Balance: {cash}")
                    stock_qty = 0
                    current_position = None

                # Take-profit triggered based on High price
                elif high_price >= entry_price * (1 + take_profit_pct):
                    cash += stock_qty * high_price
                    profit = (high_price - entry_price) * stock_qty
                    total_profit += profit
                    print(f"Take-Profit Triggered: Sold {stock_qty} shares at {high_price}, Profit: {profit}, New Cash Balance: {cash}")
                    stock_qty = 0
                    current_position = None

            # Sell Signal with Relaxed RSI Confirmation
            elif sma_short < sma_long and current_position == 'long' and rsi > 60:
                cash += stock_qty * current_price
                profit = (current_price - entry_price) * stock_qty
                total_profit += profit
                print(f"Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
                stock_qty = 0
                current_position = None

            # Debug profit/loss tracking
            print(f"Total Profit/Loss so far: {total_profit}")

        time.sleep(1)

    # Final evaluation of performance
    if current_position == 'long':
        # Sell any remaining stock at the last available price
        cash += stock_qty * current_price
        profit = (current_price - entry_price) * stock_qty
        total_profit += profit
        print(f"Final Sale: Sold {stock_qty} shares at {current_price}, Profit: {profit}, New Cash Balance: {cash}")
        stock_qty = 0
        current_position = None

    print(f"Total Profit/Loss at the end of simulation: {total_profit}")

trade_finance()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# SMA Short: 226.17301025390626, SMA Long: 226.60627975463868, RSI: 39.49120140669107
# Total Profit/Loss so far: 0
# SMA Short: 226.08000946044922, SMA Long: 226.52127990722656, RSI: 40.57542703984777
# Total Profit/Loss so far: 0
# SMA Short: 226.08209838867188, SMA Long: 226.43360977172853, RSI: 42.86405270932569
# Total Profit/Loss so far: 0
# SMA Short: 226.11846771240235, SMA Long: 226.45609436035156, RSI: 44.81758863427945
# Total Profit/Loss so far: 0
# SMA Short: 226.11346740722655, SMA Long: 226.48459396362304, RSI: 44.06549074588909
# Total Profit/Loss so far: 0
# SMA Short: 226.19046783447266, SMA Long: 226.50834426879882, RSI: 41.02472385579424
# Total Profit/Loss so far: 0
# SMA Short: 226.4159683227539, SMA Long: 226.57909469604493, RSI: 43.087974255913224
# Total Profit/Loss so far: 0
# SMA Short: 226.58645782470703, SMA Long: 226.6353446960449, RSI: 41.48751418279277
# Total Profit/Loss so far: 0
# SMA Short: 226.8124572753906, SMA Long: 226.71284408569335, RSI: 39.2426738383142
# Bought 439 shares at 227.6199951171875, Remaining Cash: 74.8221435546875
# Total Profit/Loss so far: 0
# SMA Short: 227.21895751953124, SMA Long: 226.81048889160155, RSI: 31.27952410789203
# Total Profit/Loss so far: 0
# SMA Short: 227.50596771240234, SMA Long: 226.8394889831543, RSI: 35.42196660322283
# Total Profit/Loss so far: 0
# SMA Short: 227.6899673461914, SMA Long: 226.8849884033203, RSI: 34.87788753798304
# Total Profit/Loss so far: 0
# SMA Short: 227.79946746826172, SMA Long: 226.9407829284668, RSI: 25.757896241512228
# Total Profit/Loss so far: 0
# SMA Short: 227.8499984741211, SMA Long: 226.9842330932617, RSI: 36.10808727078122
# Total Profit/Loss so far: 0
# SMA Short: 227.8999984741211, SMA Long: 227.00673294067383, RSI: 45.02232006951045
# Total Profit/Loss so far: 0
# SMA Short: 227.96649932861328, SMA Long: 227.07848358154297, RSI: 45.80698003897135
# Total Profit/Loss so far: 0
# SMA Short: 228.29399871826172, SMA Long: 227.3549835205078, RSI: 54.99464134277368
# Total Profit/Loss so far: 0
# SMA Short: 228.72649841308595, SMA Long: 227.65647811889647, RSI: 53.94710211906855
# Total Profit/Loss so far: 0
# SMA Short: 229.17649841308594, SMA Long: 227.99447784423828, RSI: 51.83350479072515
# Total Profit/Loss so far: 0
# SMA Short: 229.44449920654296, SMA Long: 228.33172836303712, RSI: 57.46339679014141
# Total Profit/Loss so far: 0
# SMA Short: 229.7324981689453, SMA Long: 228.61923294067384, RSI: 57.15158225924952
# Total Profit/Loss so far: 0
# SMA Short: 230.03949890136718, SMA Long: 228.8647331237793, RSI: 59.76500172368355
# Total Profit/Loss so far: 0
# SMA Short: 230.53999938964844, SMA Long: 229.16973342895508, RSI: 65.56780000155536
# Total Profit/Loss so far: 0
# SMA Short: 230.24649963378906, SMA Long: 229.0482490539551, RSI: 56.482516942271566
# Total Profit/Loss so far: 0
# SMA Short: 230.01300048828125, SMA Long: 228.95649948120118, RSI: 57.35476517225254
# Total Profit/Loss so far: 0
# SMA Short: 229.76230010986328, SMA Long: 228.8643997192383, RSI: 58.11548782248908
# Total Profit/Loss so far: 0
# SMA Short: 229.0572998046875, SMA Long: 228.6756492614746, RSI: 56.41518752609353
# Total Profit/Loss so far: 0
# SMA Short: 228.41330108642578, SMA Long: 228.56989974975585, RSI: 54.48750043102534
# Total Profit/Loss so far: 0
# SMA Short: 227.81631164550782, SMA Long: 228.49640502929688, RSI: 61.56214072573674
# Total Profit/Loss so far: 0
# SMA Short: 227.2778106689453, SMA Long: 228.36115493774415, RSI: 78.52972336340656
# Total Profit/Loss so far: 0
# SMA Short: 226.71881103515625, SMA Long: 228.22565460205078, RSI: 80.29206363547556
# Stop-Loss Triggered: Sold 439 shares at 223.02999877929688, Profit: -2015.0083923339844, New Cash Balance: 97984.99160766602
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.2173110961914, SMA Long: 228.1284049987793, RSI: 82.6713722451982
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.61251068115234, SMA Long: 228.07625503540038, RSI: 79.41482547690583
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.8125, SMA Long: 228.02949981689454, RSI: 72.20703331087228
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.9470001220703, SMA Long: 227.9800003051758, RSI: 71.16222200622437
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.13970031738282, SMA Long: 227.95100021362305, RSI: 78.42239426939976
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.42770080566407, SMA Long: 227.74250030517578, RSI: 39.774910335376646
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.36520080566407, SMA Long: 227.3892509460449, RSI: 42.32955654517184
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.23761138916015, SMA Long: 227.02696151733397, RSI: 42.09095808891526
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.1187316894531, SMA Long: 226.69827117919922, RSI: 37.26192043461427
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.96023254394532, SMA Long: 226.3395217895508, RSI: 43.90216082789938
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.72374267578124, SMA Long: 225.97052688598632, RSI: 47.911554779599136
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.39854278564454, SMA Long: 225.50552673339843, RSI: 41.235830065510555
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.2695526123047, SMA Long: 225.54102630615233, RSI: 40.422858161585
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.03860168457032, SMA Long: 225.4928009033203, RSI: 43.25533373546944
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.77060089111328, SMA Long: 225.45515060424805, RSI: 45.20828455561578
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.58460083007813, SMA Long: 225.5061508178711, RSI: 46.47315193178878
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.6111099243164, SMA Long: 225.48815536499023, RSI: 46.660486087331336
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.6326889038086, SMA Long: 225.43515014648438, RSI: 48.244615989401
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.73457946777344, SMA Long: 225.4266555786133, RSI: 40.24192711431586
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.0290786743164, SMA Long: 225.49465560913086, RSI: 33.51261864272632
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.17706909179688, SMA Long: 225.45040588378907, RSI: 34.04824651324944
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.31307983398438, SMA Long: 225.35581130981444, RSI: 35.67107247104701
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.17207946777344, SMA Long: 225.22081604003907, RSI: 33.04730496943384
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.1020294189453, SMA Long: 225.0703155517578, RSI: 33.17483626384433
# Bought 437 shares at 223.80999755859375, Remaining Cash: 180.02267456054688
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.0210189819336, SMA Long: 224.89580993652345, RSI: 27.854493473296245
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.78251953125, SMA Long: 224.68356018066407, RSI: 52.08197133768999
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.44450988769532, SMA Long: 224.52780990600587, RSI: 44.911048676004924
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.42550964355468, SMA Long: 224.52909927368165, RSI: 45.84024128295508
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.34949951171876, SMA Long: 224.5420394897461, RSI: 50.02277748394603
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.15350036621095, SMA Long: 224.59128952026367, RSI: 46.58368240588654
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.09550018310546, SMA Long: 224.63628463745118, RSI: 43.867282712740206
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.08246002197265, SMA Long: 224.69776992797853, RSI: 53.2675941649012
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.18346099853517, SMA Long: 224.6777702331543, RSI: 57.774538237432196
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.38046112060547, SMA Long: 224.7412452697754, RSI: 46.580931666966684
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 224.71547241210936, SMA Long: 224.86824569702148, RSI: 43.48378465870733
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.27797241210936, SMA Long: 225.03024597167968, RSI: 39.66877762051807
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 225.9769729614258, SMA Long: 225.21074142456055, RSI: 37.894517124294346
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.3729736328125, SMA Long: 225.39924163818358, RSI: 37.91635882470552
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 226.80297393798827, SMA Long: 225.57623672485352, RSI: 34.932736286427314
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 227.2283935546875, SMA Long: 225.69094696044922, RSI: 34.0742009728463
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 227.70539245605468, SMA Long: 225.90044631958008, RSI: 52.158841905000244
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.03797149658203, SMA Long: 226.06021575927736, RSI: 52.74289568849985
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.33997039794923, SMA Long: 226.2617156982422, RSI: 52.39588659519222
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.63297119140626, SMA Long: 226.50671615600587, RSI: 51.87176883262014
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.7729705810547, SMA Long: 226.74422149658204, RSI: 51.68628636705925
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.78597106933594, SMA Long: 227.03197174072267, RSI: 47.53181267172842
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.80046997070312, SMA Long: 227.38872146606445, RSI: 56.85323506322006
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.81746978759764, SMA Long: 227.59522171020507, RSI: 62.66213982601153
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.73046875, SMA Long: 227.76672134399413, RSI: 65.01972890820977
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.62054901123048, SMA Long: 227.924471282959, RSI: 66.13814420148225
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.4525588989258, SMA Long: 228.07897567749023, RSI: 66.49933273625436
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.4110092163086, SMA Long: 228.2244903564453, RSI: 67.50116740806553
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.4015106201172, SMA Long: 228.3707405090332, RSI: 62.66858109541794
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.3995101928711, SMA Long: 228.51624069213867, RSI: 69.71414381454932
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.3015106201172, SMA Long: 228.53724060058593, RSI: 62.54755172901425
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.5380096435547, SMA Long: 228.6619903564453, RSI: 65.57574040711188
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.62151031494142, SMA Long: 228.71099014282225, RSI: 68.81599665824054
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.74346008300782, SMA Long: 228.78046493530275, RSI: 68.135195450032
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 228.91045989990235, SMA Long: 228.82046432495116, RSI: 70.1946422412183
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 229.1589599609375, SMA Long: 228.88975448608397, RSI: 75.99254284596724
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 229.49821014404296, SMA Long: 228.9753845214844, RSI: 68.6469330033664
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 229.84421081542968, SMA Long: 229.12761001586915, RSI: 64.95504709827279
# Total Profit/Loss so far: -2015.0083923339844
# SMA Short: 230.6067108154297, SMA Long: 229.50411071777344, RSI: 60.2729049275125
# Take-Profit Triggered: Sold 437 shares at 237.49000549316406, Profit: 5978.163467407227, New Cash Balance: 103963.15507507324
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.28085021972657, SMA Long: 229.84018020629884, RSI: 59.13753833219417
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.00484924316407, SMA Long: 230.15317993164064, RSI: 58.55586118275933
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.33834991455078, SMA Long: 230.43817977905275, RSI: 60.95363093791243
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.7633499145508, SMA Long: 230.6924301147461, RSI: 63.086617163667576
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.0624008178711, SMA Long: 230.90293045043944, RSI: 48.01482181838275
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.39940185546874, SMA Long: 231.15493087768556, RSI: 62.58914060751999
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.4263717651367, SMA Long: 231.29266586303712, RSI: 54.555715715574934
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.36261291503905, SMA Long: 231.430411529541, RSI: 56.864611710266956
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.26661224365233, SMA Long: 231.555411529541, RSI: 56.24613876148597
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.77560119628907, SMA Long: 231.69115600585937, RSI: 58.60806417134974
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.3434616088867, SMA Long: 231.81215591430663, RSI: 59.42244762039183
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.02896270751953, SMA Long: 232.01690597534179, RSI: 67.36584283134525
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.80196228027344, SMA Long: 232.0701560974121, RSI: 78.05796902140855
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.64935150146485, SMA Long: 232.20635070800782, RSI: 75.14348379585547
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.55135040283204, SMA Long: 232.30687561035157, RSI: 71.35622996116055
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.39635009765624, SMA Long: 232.3978759765625, RSI: 67.25070814602401
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.56212005615234, SMA Long: 232.49424591064454, RSI: 66.49177833405393
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.66226959228516, SMA Long: 232.5124412536621, RSI: 62.05728521414255
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.80377044677735, SMA Long: 232.53519134521486, RSI: 67.76372326804156
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 231.93878021240235, SMA Long: 232.3571907043457, RSI: 54.40019396160922
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.30478057861328, SMA Long: 232.32412109375, RSI: 53.84796096304707
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.64727935791015, SMA Long: 232.33812103271484, RSI: 52.505787513336166
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 232.97127990722657, SMA Long: 232.38662109375, RSI: 54.28352343204723
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.25389099121094, SMA Long: 232.45162124633788, RSI: 53.791130069825094
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.58089141845704, SMA Long: 232.56612091064454, RSI: 58.944687745769464
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 233.88589172363282, SMA Long: 232.64112091064453, RSI: 50.26579408344955
# Total Profit/Loss so far: 3963.155075073242
# SMA Short: 234.14715118408202, SMA Long: 232.8546356201172, RSI: 55.54275617320869
# Total Profit/Loss so far: 3963.155075073242
# End of historical price data.
# Total Profit/Loss at the end of simulation: 3963.155075073242
